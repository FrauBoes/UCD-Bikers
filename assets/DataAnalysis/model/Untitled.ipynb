# %%
import sys
import pandas as pd
import numpy as np
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_h = pd.read_csv("mix.csv")
df_n = pd.read_csv("historic_mix.csv")

# %%
df_h.head()
# Out:
#    Unnamed: 0  STATION_NUMBER          TIME STATUS  NUMBER_OF_BIKES  \
# 0           0            42.0  1.522870e+12   OPEN             24.0
# 1           1            30.0  1.522870e+12   OPEN             14.0
# 2           2            54.0  1.522870e+12   OPEN              2.0
# 3           3            56.0  1.522870e+12   OPEN             15.0
# 4           4             6.0  1.522870e+12   OPEN              7.0
#
#    NUMBER_OF_STANDS  NUMBER_OF_SPACES                 time  weather_tamp  \
# 0              30.0               6.0  04/04/2018 20:29:32  1.522872e+12
# 1              20.0               6.0  04/04/2018 20:28:54  1.522872e+12
# 2              33.0              31.0  04/04/2018 20:29:32  1.522872e+12
# 3              40.0              25.0  04/04/2018 20:27:49  1.522872e+12
# 4              20.0              12.0  04/04/2018 20:29:27  1.522872e+12
#
#    weather_rain  weather_temperature      weather_time
# 0           0.0                 5.62  04/04/2018 21:00
# ...

# %%
df_n.head()
# Out:
#    Station No. Status           Time  Stands  Bikes Avail  Spaces Avail  Bank  \
# 0         42.0   OPEN  1521068603000      30           10            20     1
# 1         30.0   OPEN  1521068983000      20           20             0     1
# 2         54.0   OPEN  1521068619000      33            2            31     0
# 3         56.0   OPEN  1521068973000      40            6            34     0
# 4          6.0   OPEN  1521069146000      20            4            16     0
#
#         human_readible  weather_tamp  weather_rain  weather_temperature  \
# 0  14/03/2018 23:03:23  1.521072e+12          0.78                 8.45
# 1  14/03/2018 23:09:43  1.521072e+12          0.78                 8.45
# 2  14/03/2018 23:03:39  1.521072e+12          0.78                 8.45
# 3  14/03/2018 23:09:33  1.521072e+12          0.78                 8.45
# 4  14/03/2018 23:12:26  1.521072e+12          0.78                 8.45
#
#        weather_time
# 0  15/03/2018 00:00
# 1  15/03/2018 00:00
# ...

# %%
df_h.columns
# Out:
# Index(['Unnamed: 0', 'STATION_NUMBER', 'TIME', 'STATUS', 'NUMBER_OF_BIKES',
#        'NUMBER_OF_STANDS', 'NUMBER_OF_SPACES', 'time', 'weather_tamp',
#        'weather_rain', 'weather_temperature', 'weather_time'],
#       dtype='object')

# %%
df_h=df_h.drop('Unnamed: 0',1)

# %%
df_h.dtypes
# Out:
# STATION_NUMBER         float64
# TIME                   float64
# STATUS                  object
# NUMBER_OF_BIKES        float64
# NUMBER_OF_STANDS       float64
# NUMBER_OF_SPACES       float64
# time                    object
# weather_tamp           float64
# weather_rain           float64
# weather_temperature    float64
# weather_time            object
# dtype: object

# %%
df_h['STATION_NUMBER'] = df_h['STATION_NUMBER'].astype(np.int64)
df_h['TIME'] = df_h['TIME'].astype(np.int64)
df_h['NUMBER_OF_STANDS'] = df_h['NUMBER_OF_STANDS'].astype(np.int64)
df_h['NUMBER_OF_BIKES'] = df_h['NUMBER_OF_BIKES'].astype(np.int64)
df_h['NUMBER_OF_SPACES'] = df_h['NUMBER_OF_SPACES'].astype(np.int64)

# %%
df_n.columns
# Out:
# Index(['Station No.', 'Status', 'Time', 'Stands', 'Bikes Avail',
#        'Spaces Avail', 'Bank', 'human_readible', 'weather_tamp',
#        'weather_rain', 'weather_temperature', 'weather_time'],
#       dtype='object')

# %%
df_h.head()
# Out:
#    STATION_NUMBER           TIME STATUS  NUMBER_OF_BIKES  NUMBER_OF_STANDS  \
# 0              42  1522870172000   OPEN               24                30
# 1              30  1522870134000   OPEN               14                20
# 2              54  1522870172000   OPEN                2                33
# 3              56  1522870069000   OPEN               15                40
# 4               6  1522870167000   OPEN                7                20
#
#    NUMBER_OF_SPACES                 time  weather_tamp  weather_rain  \
# 0                 6  04/04/2018 20:29:32  1.522872e+12           0.0
# 1                 6  04/04/2018 20:28:54  1.522872e+12           0.0
# 2                31  04/04/2018 20:29:32  1.522872e+12           0.0
# 3                25  04/04/2018 20:27:49  1.522872e+12           0.0
# 4                12  04/04/2018 20:29:27  1.522872e+12           0.0
#
#    weather_temperature      weather_time
# 0                 5.62  04/04/2018 21:00
# ...

# %%
df_h.dropna(how='any')
# Out:
#         STATION_NUMBER           TIME  STATUS  NUMBER_OF_BIKES  \
# 0                   42  1522870172000    OPEN               24
# 1                   30  1522870134000    OPEN               14
# 2                   54  1522870172000    OPEN                2
# 3                   56  1522870069000    OPEN               15
# 4                    6  1522870167000    OPEN                7
# 5                   18  1522870158000    OPEN                3
# 6                   32  1522870041000    OPEN               10
# 7                   52  1522869917000    OPEN                1
# 8                   48  1522869656000    OPEN                5
# 9                   13  1522869756000    OPEN                6
# 10                  43  1522870095000    OPEN               16
# 11                  81  1522869752000    OPEN               36
# 12                  31  1522869818000    OPEN                8
# 13                  98  1522869840000    OPEN                0
# ...

# %%
df_n.dtypes
# Out:
# Station No.            float64
# Status                  object
# Time                     int64
# Stands                   int64
# Bikes Avail              int64
# Spaces Avail             int64
# Bank                     int64
# human_readible          object
# weather_tamp           float64
# weather_rain           float64
# weather_temperature    float64
# weather_time            object
# dtype: object

# %%
df_n['Station No.'] = df_n['Station No.'].astype(np.int64)

# %%
df_n.dropna(how='any')
# Out:
#        Station No.  Status           Time  Stands  Bikes Avail  Spaces Avail  \
# 0               42    OPEN  1521068603000      30           10            20
# 1               30    OPEN  1521068983000      20           20             0
# 2               54    OPEN  1521068619000      33            2            31
# 3               56    OPEN  1521068973000      40            6            34
# 4                6    OPEN  1521069146000      20            4            16
# 5               18    OPEN  1521068879000      30            7            23
# 6               32    OPEN  1521068782000      30            0            30
# 7               52    OPEN  1521069140000      32            3            29
# 8               48    OPEN  1521068970000      40            9            31
# 9               13    OPEN  1521068602000      30            0            30
# 10              43    OPEN  1521068852000      30           20            10
# ...

# %%
df=df_n.drop(["human_readible","weather_tamp","weather_time"],1)

# %%
df.head()
# Out:
#    Station No. Status           Time  Stands  Bikes Avail  Spaces Avail  Bank  \
# 0           42   OPEN  1521068603000      30           10            20     1
# 1           30   OPEN  1521068983000      20           20             0     1
# 2           54   OPEN  1521068619000      33            2            31     0
# 3           56   OPEN  1521068973000      40            6            34     0
# 4            6   OPEN  1521069146000      20            4            16     0
#
#    weather_rain  weather_temperature
# 0          0.78                 8.45
# 1          0.78                 8.45
# 2          0.78                 8.45
# 3          0.78                 8.45
# 4          0.78                 8.45

# %%
df_2=df_h.drop(["time","weather_tamp","weather_time"],1)

# %%
df_2.head()
# Out:
#    STATION_NUMBER           TIME STATUS  NUMBER_OF_BIKES  NUMBER_OF_STANDS  \
# 0              42  1522870172000   OPEN               24                30
# 1              30  1522870134000   OPEN               14                20
# 2              54  1522870172000   OPEN                2                33
# 3              56  1522870069000   OPEN               15                40
# 4               6  1522870167000   OPEN                7                20
#
#    NUMBER_OF_SPACES  weather_rain  weather_temperature
# 0                 6           0.0                 5.62
# 1                 6           0.0                 5.62
# 2                31           0.0                 5.62
# 3                25           0.0                 5.62
# 4                12           0.0                 5.62

# %%
df_name = df.columns

# %%
df_name
# Out:
# Index(['Station No.', 'Status', 'Time', 'Stands', 'Bikes Avail',
#        'Spaces Avail', 'Bank', 'weather_rain', 'weather_temperature'],
#       dtype='object')

# %%
df.rename(columns={'Station No.': 'STATION_NUMBER','Time':'TIME','Status':"STATUS",'Stands':'NUMBER_OF_STANDS','Bikes Avail':'NUMBER_OF_BIKES','Spaces Avail':'NUMBER_OF_SPACES'})
# Out:
#        STATION_NUMBER  STATUS           TIME  NUMBER_OF_STANDS  \
# 0                  42    OPEN  1521068603000                30
# 1                  30    OPEN  1521068983000                20
# 2                  54    OPEN  1521068619000                33
# 3                  56    OPEN  1521068973000                40
# 4                   6    OPEN  1521069146000                20
# 5                  18    OPEN  1521068879000                30
# 6                  32    OPEN  1521068782000                30
# 7                  52    OPEN  1521069140000                32
# 8                  48    OPEN  1521068970000                40
# 9                  13    OPEN  1521068602000                30
# 10                 43    OPEN  1521068852000                30
# 11                 81    OPEN  1521068992000                40
# 12                 31    OPEN  1521068723000                20
# 13                 98    OPEN  1521068772000                30
# ...

# %%
df =
